# %%
import torch 
import numpy as np 
import torch.nn as nn
import torch.optim as optim 
import matplotlib.pyplot as plt

# %% [markdown]
# #Regresion lineal

# %%
car_prices = [5,6,7,8,9,10]
units_sold = [8.5, 8,7.5,7.0, 6.5, 6.0]
plt.scatter(car_prices, units_sold)

# %%
prices_array = np.array(car_prices).reshape(-1,1)
unit_array = np.array(units_sold).reshape(-1,1)

print(unit_array)
print(prices_array)
# Out:
# [[8.5]
#  [8. ]
#  [7.5]
#  [7. ]
#  [6.5]
#  [6. ]]
# [[ 5]
#  [ 6]
#  [ 7]
#  [ 8]
#  [ 9]
#  [10]]

# %%
prices = torch.from_numpy(prices_array).float().requires_grad_(True)
units = torch.from_numpy(unit_array).float()
prices, prices.shape
# Out:
# (tensor([[ 5.],
#          [ 6.],
#          [ 7.],
#          [ 8.],
#          [ 9.],
#          [10.]], requires_grad=True), torch.Size([6, 1]))

# %%
model = nn.Linear(1,1)
loss_function = nn.MSELoss()
optimizer = optim.SGD(model.parameters(), lr = 0.015)

losses = []
iterations = 2000

for i in range(iterations):
  pred = model(prices)
  loss = loss_function(pred, units)
  losses.append(loss.data)

  optimizer.zero_grad()
  loss.backward()
  optimizer.step()

print(float(loss))

plt.plot(range(iterations), losses)
# Out:
# 0.0180137250572443

# %%
x = torch.Tensor([[9.5]])
p = model(x)
#de acuerdo al precio puedo predecir la cantidad de ventas
p
# Out:
# tensor([[6.2501]], grad_fn=<AddmmBackward>)
